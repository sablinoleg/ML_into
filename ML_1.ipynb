# %%
import pandas as pd
data = pd.read_csv( 'titanic.csv' , index_col='PassengerId')
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# 1. Какое количество мужчин и женщин ехало на корабле? В качестве ответа приведите два числа через пробел

# %%
count_sex=data['Sex'].value_counts().to_list()
print(count_sex[0],count_sex[1])
# Out:
# 577 314

# %% [markdown]
# 2. Какой части пассажиров удалось выжить? Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
round((data['Survived'].sum()/data.shape[0])*100,2)
# Out:
# 38.38

# %% [markdown]
#  3. Какую долю пассажиры первого класса составляли среди всех пассажиров? Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
round((data[data['Pclass']==1].shape[0]/data.shape[0])*100,2)
# Out:
# 24.24

# %% [markdown]
#  4. Какого возраста были пассажиры? Посчитайте среднее и медиану возраста пассажиров. Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.

# %%
average_mediana=data['Age'].describe().iloc[1:6:4].to_list()# можно и через mean и median
print(round(average_mediana[0],2),average_mediana[1])
# Out:
# 29.7 28.0

# %% [markdown]
#  5. Коррелируют ли число братьев/сестер с числом родителей/детей?
#  Посчитайте корреляцию Пирсона между признаками SibSp и Parch.

# %%
matrix_corr=data[['Parch','SibSp']].corr()
matrix_corr
# Out:
#           Parch     SibSp
# Parch  1.000000  0.414838
# SibSp  0.414838  1.000000

# %% [markdown]
# 6. Какое самое популярное женское имя на корабле? Извлеките из полного имени пассажира (колонка Name) его личное имя (First Name). Это задание типичный пример того, с чем сталкивается специалист по анализу данных. Данные очень разнородные и шумные, но из них требуется извлечь необходимую информацию.
#  Попробуйте вручную разобрать несколько значений столбца Name и выработать правило для извлечения имен, а также разделения
#  их на женские и мужские.

# %%
woman=data[data['Sex']=='female']
woman['Name'].str.split(',').str[1].str.split('.').str[0].unique()
# Out:
# array([' Mrs', ' Miss', ' Mme', ' Ms', ' Lady', ' Mlle', ' the Countess',
#        ' Dr'], dtype=object)

# %%
import re
def name_female(name):
    match = re.search("^[^,]+, (.*)", name)#после запятой
    if match:
        name = match[1]

    match = re.search("\(([^)]+)\)", name) #в скобках
    if match:
        name = match[1]
    name = re.sub("(Miss\. |Mrs\. |Ms\. |Mlle\. |Mme\. |Lady\. |Dr\. |the Countess\. )", "", name)#исключаем статусы


    name = name.split(" ")[0].replace('"','')#первое как раз нужное нам имя

    return name

# %%
names = data[data["Sex"] == "female"]["Name"].map(name_female)
names.value_counts()
# Out:
# Name
# Mary           15
# Anna           15
# Elizabeth      11
# Margaret       10
# Alice           6
# Helen           5
# Bertha          5
# Marie           4
# Ada             4
# Maria           4
# Marion          4
# Emily           4
# Annie           4
# Catherine       4
# Augusta         4
# Florence        4
# Ellen           4
# Ida             3
# Katherine       3
# Mrs             3
# Edith           3
# Jane            3
# Madeleine       3
# Amelia          3
# Hanora          3
# Lillian         3
# Elisabeth       3
# Martha          2
# Rosa            2
# Amy             2
# Marjorie        2
# Kate            2
# Helene          2
# Charlotte       2
# Lucile          2
# Agnes           2
# Emma            2
# Elsie           2
# Ethel           2
# Lucy            2
# Hedwig          2
# Jessie          2
# Marija          2
# Rosalie         2
# Clara           2
# Bridget         2
# Lily            2
# Dorothy         2
# Johanna         2
# ...
